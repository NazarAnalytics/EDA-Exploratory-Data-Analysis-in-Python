# %% [markdown]
# # Retail Data Analytics

# %%
import math
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("RetailStoreUS.xlsx")

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# 5      24847         Medium      0.05        3.28           4.20           14
# 6      24848         Medium      0.05        3.58           1.63           14
# 7      18181       Critical      0.00        4.42           4.99           15
# 8      20925         Medium      0.01       35.94           6.66           15
# 9      26267           High      0.04        2.98           1.58           16
# 10     26268           High      0.05      115.99           2.50           16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
# Row ID                  1952 non-null int64
# Order Priority          1952 non-null object
# Discount                1952 non-null float64
# Unit Price              1952 non-null float64
# Shipping Cost           1952 non-null float64
# Customer ID             1952 non-null int64
# Customer Name           1952 non-null object
# Ship Mode               1952 non-null object
# Customer Segment        1952 non-null object
# Product Category        1952 non-null object
# Product Sub-Category    1952 non-null object
# Product Container       1952 non-null object
# Product Name            1952 non-null object
# Product Base Margin     1936 non-null float64
# Country                 1952 non-null object
# Region                  1952 non-null object
# State or Province       1952 non-null object
# City                    1952 non-null object
# ...

# %%
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1952.000000  1952.000000  1952.000000    1952.000000  1952.000000
# mean   19916.479508     0.048975   109.079221      12.968151  1735.376537
# std     5957.595627     0.031378   393.481301      17.414631   991.078006
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19121.000000     0.020000     6.480000       3.230000   875.000000
# 50%    21164.500000     0.050000    20.990000       6.150000  1738.000000
# 75%    23483.250000     0.080000   100.972500      14.362500  2578.250000
# max    26389.000000     0.210000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          1936.000000   1952.000000   1952.000000           1952.000000
# mean              0.515186  51534.769467    114.793859             12.944672
# ...

# %%
df.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
#       Customer Name    Ship Mode Customer Segment Product Category   ...     \
# 1947    Andrea Shaw  Regular Air   Small Business  Office Supplies   ...
# 1948    Andrea Shaw  Regular Air   Small Business       Technology   ...
# 1949    Marvin Reid  Regular Air   Small Business  Office Supplies   ...
# 1950  Florence Gold  Express Air   Small Business        Furniture   ...
# 1951  Tammy Buckley  Express Air         Consumer        Furniture   ...
#
# ...

# %%
df.head(5)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies
#
#     ...      Region State or Province         City  Postal Code Order Date  \
# ...

# %%
df.isnull()
# Out:
#       Row ID  Order Priority  Discount  Unit Price  Shipping Cost  \
# 0      False           False     False       False          False
# 1      False           False     False       False          False
# 2      False           False     False       False          False
# 3      False           False     False       False          False
# 4      False           False     False       False          False
# 5      False           False     False       False          False
# 6      False           False     False       False          False
# 7      False           False     False       False          False
# 8      False           False     False       False          False
# 9      False           False     False       False          False
# 10     False           False     False       False          False
# 11     False           False     False       False          False
# 12     False           False     False       False          False
# ...

# %%
df.count()
# Out:
# Row ID                  1952
# Order Priority          1952
# Discount                1952
# Unit Price              1952
# Shipping Cost           1952
# Customer ID             1952
# Customer Name           1952
# Ship Mode               1952
# Customer Segment        1952
# Product Category        1952
# Product Sub-Category    1952
# Product Container       1952
# Product Name            1952
# Product Base Margin     1936
# Country                 1952
# Region                  1952
# State or Province       1952
# City                    1952
# Postal Code             1952
# Order Date              1952
# Ship Date               1952
# Profit                  1952
# Quantity ordered new    1952
# Sales                   1952
# Order ID                1952
# dtype: int64

# %%
df.tail(5)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
#       Customer Name    Ship Mode Customer Segment Product Category   ...     \
# 1947    Andrea Shaw  Regular Air   Small Business  Office Supplies   ...
# 1948    Andrea Shaw  Regular Air   Small Business       Technology   ...
# 1949    Marvin Reid  Regular Air   Small Business  Office Supplies   ...
# 1950  Florence Gold  Express Air   Small Business        Furniture   ...
# 1951  Tammy Buckley  Express Air         Consumer        Furniture   ...
#
# ...

# %%
len(df)
# Out:
# 1952

# %%
df.sum()
# Out:
# Row ID                                                           38876968
# Order Priority          HighNot SpecifiedCriticalMediumMediumMediumMed...
# Discount                                                             95.6
# Unit Price                                                         212923
# Shipping Cost                                                     25313.8
# Customer ID                                                       3387455
# Customer Name           Bonnie PotterRonnie ProctorMarcus DunlapGwendo...
# Ship Mode               Express AirDelivery TruckRegular AirRegular Ai...
# Customer Segment        CorporateHome OfficeHome OfficeSmall BusinessS...
# Product Category        Office SuppliesFurnitureFurnitureFurnitureOffi...
# Product Sub-Category    Pens & Art SuppliesChairs & ChairmatsOffice Fu...
# Product Container       Wrap BagJumbo DrumSmall PackSmall BoxWrap BagW...
# Product Name            SANFORD Liquid Accent™ Tank-Style Highlighters...
# ...

# %%
df.mean()
# Out:
# Row ID                  19916.479508
# Discount                    0.048975
# Unit Price                109.079221
# Shipping Cost              12.968151
# Customer ID              1735.376537
# Product Base Margin         0.515186
# Postal Code             51534.769467
# Profit                    114.793859
# Quantity ordered new       12.944672
# Sales                     985.828832
# Order ID                82365.924180
# dtype: float64

# %%
df.count()
# Out:
# Row ID                  1952
# Order Priority          1952
# Discount                1952
# Unit Price              1952
# Shipping Cost           1952
# Customer ID             1952
# Customer Name           1952
# Ship Mode               1952
# Customer Segment        1952
# Product Category        1952
# Product Sub-Category    1952
# Product Container       1952
# Product Name            1952
# Product Base Margin     1936
# Country                 1952
# Region                  1952
# State or Province       1952
# City                    1952
# Postal Code             1952
# Order Date              1952
# Ship Date               1952
# Profit                  1952
# Quantity ordered new    1952
# Sales                   1952
# Order ID                1952
# dtype: int64

# %%
df.min()
# Out:
# Row ID                                                                 64
# Order Priority                                                   Critical
# Discount                                                                0
# Unit Price                                                           1.14
# Shipping Cost                                                        0.49
# Customer ID                                                             3
# Customer Name                                                   Aaron Day
# Ship Mode                                                  Delivery Truck
# Customer Segment                                                 Consumer
# Product Category                                                Furniture
# Product Sub-Category                                           Appliances
# Product Container                                               Jumbo Box
# Product Name            "While you Were Out" Message Book, One Form pe...
# ...

# %%
df.max()
# Out:
# Row ID                                         26389
# Order Priority                         Not Specified
# Discount                                        0.21
# Unit Price                                   6783.02
# Shipping Cost                                 164.73
# Customer ID                                     3403
# Customer Name                        Zachary Maynard
# Ship Mode                                Regular Air
# Customer Segment                      Small Business
# Product Category                          Technology
# Product Sub-Category    Telephones and Communication
# Product Container                           Wrap Bag
# Product Name                                i500plus
# Product Base Margin                             0.85
# Country                                United States
# Region                                          West
# State or Province                            Wyoming
# City                                         Yucaipa
# ...

# %%
df.std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ce97bb7eaef8> in <module>()
# ----> 1 df.std()
#
# NameError: name 'df' is not defined

# %%
df.var()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-28ded241fd7c> in <module>()
# ----> 1 df.var()
#
# NameError: name 'df' is not defined

# %%
df.plot.hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aae26ac4cd3e> in <module>()
# ----> 1 df.plot.hist()
#
# NameError: name 'df' is not defined
